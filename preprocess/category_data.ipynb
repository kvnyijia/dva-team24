# %%
import pandas as pd
import numpy as np
import math

# %%
path = '../data/Preprocessed_data.csv'
df4 = pd.read_csv(path)

# %%
df4.head()
# Out:
#    Unnamed: 0  user_id                   location      age        isbn  \
# 0           0        2  stockton, california, usa  18.0000  0195153448
# 1           1        8   timmins, ontario, canada  34.7439  0002005018
# 2           2    11400    ottawa, ontario, canada  49.0000  0002005018
# 3           3    11676              n/a, n/a, n/a  34.7439  0002005018
# 4           4    41385   sudbury, ontario, canada  34.7439  0002005018
#
#    rating           book_title           book_author  year_of_publication  \
# 0       0  Classical Mythology    Mark P. O. Morford               2002.0
# 1       5         Clara Callan  Richard Bruce Wright               2001.0
# 2       0         Clara Callan  Richard Bruce Wright               2001.0
# 3       8         Clara Callan  Richard Bruce Wright               2001.0
# 4       0         Clara Callan  Richard Bruce Wright               2001.0
#
#                  publisher                                              img_s  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_m  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_l  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                              Summary Language  \
# 0  Provides an introduction to classical myths pl...       en
# 1  In a small town in Canada, Clara Callan reluct...       en
# 2  In a small town in Canada, Clara Callan reluct...       en
# 3  In a small town in Canada, Clara Callan reluct...       en
# 4  In a small town in Canada, Clara Callan reluct...       en
#
#              Category      city       state country
# 0  ['Social Science']  stockton  california     usa
# 1       ['Actresses']   timmins     ontario  canada
# 2       ['Actresses']    ottawa     ontario  canada
# 3       ['Actresses']       NaN         NaN     NaN
# 4       ['Actresses']   sudbury     ontario  canada

# %%
df4 = df4.loc[df4['Category'] != '9']

# %%
df4['newCategory'] = df4['Category'].apply(lambda x: x[2:-2])

# %%
df4.head()
# Out:
#    Unnamed: 0  user_id                   location      age        isbn  \
# 0           0        2  stockton, california, usa  18.0000  0195153448
# 1           1        8   timmins, ontario, canada  34.7439  0002005018
# 2           2    11400    ottawa, ontario, canada  49.0000  0002005018
# 3           3    11676              n/a, n/a, n/a  34.7439  0002005018
# 4           4    41385   sudbury, ontario, canada  34.7439  0002005018
#
#    rating           book_title           book_author  year_of_publication  \
# 0       0  Classical Mythology    Mark P. O. Morford               2002.0
# 1       5         Clara Callan  Richard Bruce Wright               2001.0
# 2       0         Clara Callan  Richard Bruce Wright               2001.0
# 3       8         Clara Callan  Richard Bruce Wright               2001.0
# 4       0         Clara Callan  Richard Bruce Wright               2001.0
#
#                  publisher                                              img_s  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_m  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                                img_l  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                              Summary Language  \
# 0  Provides an introduction to classical myths pl...       en
# 1  In a small town in Canada, Clara Callan reluct...       en
# 2  In a small town in Canada, Clara Callan reluct...       en
# 3  In a small town in Canada, Clara Callan reluct...       en
# 4  In a small town in Canada, Clara Callan reluct...       en
#
#              Category      city       state country     newCategory
# 0  ['Social Science']  stockton  california     usa  Social Science
# 1       ['Actresses']   timmins     ontario  canada       Actresses
# 2       ['Actresses']    ottawa     ontario  canada       Actresses
# 3       ['Actresses']       NaN         NaN     NaN       Actresses
# 4       ['Actresses']   sudbury     ontario  canada       Actresses

# %%
dfcat = df4.groupby(['newCategory']).agg({'user_id': 'count'})

# %%
dfcat = dfcat.loc[dfcat['user_id'] > 200]

# %%
catList = dfcat.index.tolist()

# %%
dfcat = dfcat.reset_index()
dfcat = dfcat.sort_values(by='user_id', ascending=False)
dfcat['log_count'] = dfcat['user_id'].apply(lambda x: math.log(x, 2))
dfcat = dfcat.rename(columns={'user_id': 'count', 'newCategory': 'Category'})

# %%
dfcat.head()
# Out:
#                      Category   count  log_count
# 57                    Fiction  385135  18.555005
# 74           Juvenile Fiction   39617  15.273832
# 21  Biography & Autobiography   22390  14.450567
# 71                      Humor    8500  13.053247
# 68                    History    8249  13.010004

# %%
dfcat.to_csv('../data/cat_count_sort.csv', index=False)

# %%
df4 = df4.loc[df4['newCategory'].isin(catList)]
df4.head()
# Out:
#     Unnamed: 0  user_id                    location      age        isbn  \
# 0            0        2   stockton, california, usa  18.0000  0195153448
# 18          18        8    timmins, ontario, canada  34.7439  0374157065
# 19          19    35704  kansas city, missouri, usa  53.0000  0374157065
# 20          20    83160    oregon city, oregon, usa  65.0000  0374157065
# 21          21   110912   milpitas, california, usa  36.0000  0374157065
#
#     rating                                         book_title  \
# 0        0                                Classical Mythology
# 18       0  Flu: The Story of the Great Influenza Pandemic...
# 19       6  Flu: The Story of the Great Influenza Pandemic...
# 20       0  Flu: The Story of the Great Influenza Pandemic...
# 21      10  Flu: The Story of the Great Influenza Pandemic...
#
#            book_author  year_of_publication                publisher  \
# 0   Mark P. O. Morford               2002.0  Oxford University Press
# 18    Gina Bari Kolata               1999.0     Farrar Straus Giroux
# 19    Gina Bari Kolata               1999.0     Farrar Straus Giroux
# 20    Gina Bari Kolata               1999.0     Farrar Straus Giroux
# 21    Gina Bari Kolata               1999.0     Farrar Straus Giroux
#
#                                                 img_s  \
# 0   http://images.amazon.com/images/P/0195153448.0...
# 18  http://images.amazon.com/images/P/0374157065.0...
# 19  http://images.amazon.com/images/P/0374157065.0...
# 20  http://images.amazon.com/images/P/0374157065.0...
# 21  http://images.amazon.com/images/P/0374157065.0...
#
#                                                 img_m  \
# 0   http://images.amazon.com/images/P/0195153448.0...
# 18  http://images.amazon.com/images/P/0374157065.0...
# 19  http://images.amazon.com/images/P/0374157065.0...
# 20  http://images.amazon.com/images/P/0374157065.0...
# 21  http://images.amazon.com/images/P/0374157065.0...
#
#                                                 img_l  \
# 0   http://images.amazon.com/images/P/0195153448.0...
# 18  http://images.amazon.com/images/P/0374157065.0...
# 19  http://images.amazon.com/images/P/0374157065.0...
# 20  http://images.amazon.com/images/P/0374157065.0...
# 21  http://images.amazon.com/images/P/0374157065.0...
#
#                                               Summary Language  \
# 0   Provides an introduction to classical myths pl...       en
# 18  Describes the great flu epidemic of 1918, an o...       en
# 19  Describes the great flu epidemic of 1918, an o...       en
# 20  Describes the great flu epidemic of 1918, an o...       en
# 21  Describes the great flu epidemic of 1918, an o...       en
#
#               Category         city       state country     newCategory
# 0   ['Social Science']     stockton  california     usa  Social Science
# 18         ['Medical']      timmins     ontario  canada         Medical
# 19         ['Medical']  kansas city    missouri     usa         Medical
# 20         ['Medical']  oregon city      oregon     usa         Medical
# 21         ['Medical']     milpitas  california     usa         Medical

# %%
dfg = df4.groupby(['newCategory', 'isbn', 'img_s', 'img_l', 'book_title']).agg({'user_id': 'count', 'rating': 'mean'})
dfg['log_user_id_cnt'] = dfg['user_id'].apply(lambda x: math.log(x, 2))


user_cnt_max = dfg['log_user_id_cnt'].max()
rating_max = dfg['rating'].max()
dfg['weight'] = dfg[['log_user_id_cnt', 'rating']].apply(lambda x: x[0] / user_cnt_max * 70 + x[1] / rating_max * 30, axis=1)

# %%
g = dfg['weight'].groupby('newCategory', group_keys=False)

# %%
res = g.apply(lambda x: x.sort_values(ascending=False))

# %%
res = res.reset_index()

# %%
res = res.rename(columns={'newCategory': 'Category'})

# %%
res.head()
# Out:
#    Category        isbn                                              img_s  \
# 0  Abortion  0451183665  http://images.amazon.com/images/P/0451183665.0...
# 1  Abortion  0830714596  http://images.amazon.com/images/P/0830714596.0...
# 2  Abortion  0891074961  http://images.amazon.com/images/P/0891074961.0...
# 3  Abortion  0385327587  http://images.amazon.com/images/P/0385327587.0...
# 4  Abortion  0553196480  http://images.amazon.com/images/P/0553196480.0...
#
#                                                img_l  \
# 0  http://images.amazon.com/images/P/0451183665.0...
# 1  http://images.amazon.com/images/P/0830714596.0...
# 2  http://images.amazon.com/images/P/0891074961.0...
# 3  http://images.amazon.com/images/P/0385327587.0...
# 4  http://images.amazon.com/images/P/0553196480.0...
#
#                                           book_title     weight
# 0                                     A Case of Need  53.645806
# 1  I'll Hold You in Heaven: Healings and Hope for...  31.151600
# 2                                              Tilly  27.000000
# 3                                     Borrowed Light  22.828035
# 4                                  Cider House Rules  16.901600

# %%
# Output
res.to_csv('../data/cat_score_sort.csv')
